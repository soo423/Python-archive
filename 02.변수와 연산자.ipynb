# %% [markdown]
# # 📘 파이썬 기초: 02. 변수와 연산자

# %% [markdown]
# ## 1. 변수 (Variable)
#
# * **개념**: 프로그램 실행 중 값을 저장하는 메모리 공간.
# * **특징**: 변수에는 하나의 값만 저장되며, 새로운 값을 넣으면 기존 값은 삭제됨.
# * **대입 연산자 (`=`)**: 오른쪽의 값을 왼쪽 변수에 저장함.
# * 예: `age = 20` (age라는 변수에 20을 대입)

# %% [markdown]
# ## 2. 자료형 (Data Type)
#
# 데이터의 종류에 따라 적절한 자료형을 사용해야 합니다.
#
# * **정수형 (int)**: 소수점이 없는 숫자 (예: 10, -5)
# * **실수형 (float)**: 소수점이 있는 숫자 (예: 3.14, 0.5)
# * **문자열 (str)**: 따옴표(`'`, `"`)로 감싸진 텍스트 (예: "Hello", 'Python')
# * **불형 (bool)**: 참(`True`) 또는 거짓(`False`)을 나타냄

# %% [markdown]
# ## 3. 입력과 출력
#
# * **출력 (`print`)**: 변수나 값을 화면에 표시.
# * `print('age')`는 문자열 출력, `print(age)`는 변수 값 출력.
#
# * **입력 (`input`)**: 사용자로부터 데이터를 입력받음.
# * **주의**: `input()`으로 받은 데이터는 기본적으로 **문자열**로 처리되므로, 계산이 필요하면 `int()`나 `float()`로 변환해야 함.

# %%
name = input('이름을 입력하세요')
age = input('나이를 입력하세요')
print('이름 : ', name, '나이: ', age)
# Out:
# 이름을 입력하세요최진우
# 나이를 입력하세요30
# 이름 :  최진우 나이:  30

# %%
a = input('정수')
b = input('정수')
print(a+b)
# Out:
# 정수56
# 정수59
# 5659

# %%
a = int(input('정수 '))
b = int(input('정수 '))
print(a - b)
# Out:
# 정수5
# 정수9
# -4

# %%
minute = float(input('분 단위 시간'))
second = minute * 60
print(second, '초')
# Out:
# 분 단위 시간1440
# 86400.0 초

# %%
print('반갑습니다')
score = 90
print('귀하의 점수는', score, '점입니다')
# Out:
# 반갑습니다
# 귀하의 점수는 90 점입니다

# %%
a = 25
b = 45
print(a, end =' ')
print(b)
# Out:
# 25 45

# %%
print('안녕하세요')
print()
print('Python')
# Out:
# 안녕하세요
#
# Python

# %%
name = '홍길동'
age = 20
print('이름은', name, '이며 나이는', age, '입니다')
print(f'{name:5}:{age:3}')
# Out:
# 이름은 홍길동 이며 나이는 20 입니다
# 홍길동  : 20

# %%
a = 25
b = 1234
c = 4
print(f'{a:5d}')
print(f'{b:5d}')
print(f'20{c:02d}')
# Out:
#    25
#  1234
# 2004

# %%
a = 3.14159265
print(f'{a}, {a:.3f}')
print(f'{a:7.3f}')
# Out:
# 3.14159265, 3.142
#   3.142

# %%
#원의 넓이를 구하는 식
pi = 3.14159256
radius = int(input('원의 반지름: '))
area = pi * radius ** 2 #pi * radius * radius
print(f'반지름이 {radius}인 원의 넓이는{area:.3f}')
# Out:
# 원의 반지름: 7
# 반지름이 7인 원의 넓이는153.938

# %% [markdown]
# #f문자열(f-String): 문자열 앞에 소문자 또는 대문자를 문자열 안에 변수를 중괄호({})로 감싸서
# 표현하는 것
#
# *   변수 값이 출력되는 형식을 지정할 수 있음
# *   변수명 옆에 콜론(:)을 넣고 그 다음에 형식을 지정
# *   중괄호 안에 d는 정수를 의미하고, f는 부등소수점수를 의미함

# %%
#f문자열(f-String): 문자열 앞에 소문자 또는 대문자를 문자열 안에 변수를 중괄호({})로 감싸서 표현하는 것

# %%
print(f'문자열 {222}')

name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age} 입니다')
# Out:
# 문자열 222
# 이름은 홍길동이고 나이는 20 입니다

# %% [markdown]
# ## 4. 연산자 (Operators)
#
# 산술 연산자를 통해 데이터를 계산합니다.
#
# | 연산자 | 기능 | 예시 (a=10, b=3) | 결과 |
# | --- | --- | --- | --- |
# | `+` | 더하기 | `a + b` | 13 |
# | `-` | 빼기 | `a - b` | 7 |
# | `*` | 곱하기 | `a * b` | 30 |
# | `/` | 나누기 (실수) | `a / b` | 3.333... |
# | `//` | **몫** | `a // b` | 3 |
# | `%` | **나머지** | `a % b` | 1 |
# | `**` | 거듭제곱 | `a ** b` | 1000 |

# %%
a = int(input('정수 : '))
b = int(input('정수 : '))
print(f'{a} + {b} = {a+b}')
# Out:
# 정수 : 5
# 정수 : 5
# 5 + 5 = 10

# %%
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} % {b} = {a%b}')
print(f'{a} // {b} = {a//b}')
print(f'{a} %% {b} = {a%b}')
print(f'{a} ** {b} = {a**b}')
# Out:
#   File "/tmp/ipython-input-791144414.py", line 6
#     print(f'{a} %% {b} = {a!%b}')
#                             ^
# SyntaxError: f-string: invalid conversion character

# %% [markdown]
# ### 연산자 우선 순위
#
#
# 1.   **거듭제곱
# 2.   + 양수 / - 음수
# 3.   *,/,//, %
# 4.   +, -
# 5.   <. <=, >
# 6.   ==. != 동등연산자
# =, +=, /=, //=, %=, **= 대입연산자
# 7.   not 연산자
# 8.   or 논리연산자
# 9.   and 논리연산자

# %%
ave = (70 + 80 + 90) / 3
print(ave)
# Out:
# 80.0

# %%
a = 2
b = 3
c = 4
print(a + b ** c * c)
# Out:
# 326

# %%
#남여 비율 계산하기
male_num = int(input('남성 지원자 수 :'))
female_num = int(input('여성 지원자 수 :'))
total = male_num + female_num
print(f'남성 지원자 비율 : {male_num / total:.2f} 여성 지원자 비율 : {female_num / total:.2f}')
# Out:
# 남성 지원자 수 :15400
# 여성 지원자 수 :10000
# 남성 지원자 비율 : 0.61 여성 지원자 비율 : 0.39

# %%
#길이 단위 변환하기
cm = int(input('cm의 길이 :'))
m = cm //100 #100cm를 1m로 나눔
cm = cm % 100
print(f'{m}m {cm}cm')
# Out:
# cm의 길이 :222
# 2m 22cm

# %% [markdown]
# ## 5. [실습 예제]
# ### ⏱ 시간 단위 변환기
# 1. **데이터 입력**: 사용자로부터 초(second) 단위의 큰 숫자를 입력받아 정수로 변환합니다.
# 2. **시간/분 계산**:
#     * 전체 초를 3,600으로 나눈 **몫**을 '시간'으로 저장합니다.
#     * 남은 초를 다시 60으로 나눈 **몫**은 '분', **나머지**는 최종적인 '초'가 됩니다.
# 3. **결과 출력**: 계산된 시간, 분, 초를 조합하여 화면에 보여줍니다.

# %%
seconds = int(input('초 입력 : '))
hours = seconds // 3600
minutes = (seconds % 3600) // 60
seconds = (seconds % 3600) % 60
print(f'{hours}시간 {minutes}분 {seconds}초')
# Out:
# 초 입력 : 11000
# 3시간 3분 20초

# %% [markdown]
# ### 💰 주문 금액 계산기
# 1. **정보 입력**: 상품 가격과 주문 수량을 각각 입력받아 숫자로 변환합니다.
# 2. **금액 산출**: (상품 가격 × 수량) 로직을 통해 총 주문 금액을 계산합니다.
# 3. **포맷팅**: "총 주문 금액은 OOO원입니다"와 같은 형태로 가독성 있게 출력합니다.

# %% [markdown]
# 1. 음료 주문 수 입력
# * Americano 2000
# * Latte 3000
# * Greentea 2500
# * 주문 금액을 sum으로 출력

# %%
a = 2000
b = 3000
c = 2500

americano = int(input('아메리카노 주문 수량 입력'))
latte = int(input('라떼 주문 수량 입력'))
greentea = int(input('그린티 주문 수량 입력'))

sum = americano * a + latte * b + greentea * c
print(f'아메리카노 : {americano}개 / 가격 {americano * a}')
print(f'라떼 : {latte}개 / 가격 {latte * b}')
print(f'그린티 : {greentea}개 / 가격 {greentea * c}')
print(f'주문 금액 결과 : {sum}원')
# Out:
# 아메리카노 주문 수량 입력2
# 라떼 주문 수량 입력1
# 그린티 주문 수량 입력3
# 아메리카노 : 2개 / 가격 4000
# 라떼 : 1개 / 가격 3000
# 그린티 : 3개 / 가격 7500
# 주문 금액 결과 : 14500원

# %% [markdown]
# 1. 음료 가격을 변수에 지정
#
# *   americano_price 2000
# *   latte_price = 3000
# *  greentea_price = 2500

# %%
americano_price = 2000
latte_price = 3000
greentea_price = 2500

americano = int(input('아메리카노 주문 수량 입력'))
latte = int(input('라떼 주문 수량 입력'))
greentea = int(input('그린티 주문 수량 입력'))

sum = americano_price * americano + latte_price * latte + greentea_price * greentea
print(f'주문 금액 결과 : {sum}원')
# Out:
# 아메리카노 주문 수량 입력2
# 라떼 주문 수량 입력2
# 그린티 주문 수량 입력2
# 주문 금액 결과 : 15000원
