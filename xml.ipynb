# %% [markdown]
# <a href="https://colab.research.google.com/github/soo423/Python-archive/blob/main/xml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#xml
import xml.etree.ElementTree as ET #XML 데이터를 처리하기 위한 ElementTree 모듈
#xml 문자열
x_str = """
  <movie>
    <title>어벤져스</title>
    <director>조스 웨던</director>
    <year>2012</year>
  </movie>
"""

#XML 문자열 > XML 객체로 변환
movie = ET.fromstring(x_str) #XML Element 객체로 파싱
type(movie)
# Out:
# xml.etree.ElementTree.Element

# %%
print(movie.tag)
# Out:
# movie

# %%
#자식 엘리먼트를 리스트로 변환
children = list(movie)
children
# Out:
# [<Element 'title' at 0x788fd086dd50>,
#  <Element 'director' at 0x788fd086ddf0>,
#  <Element 'year' at 0x788fd086de90>]

# %%
print(movie.findtext())

# %%
#findtext()로 특정 태그의 텍스트 추출
print(movie.findtext('title'))
print(movie.findtext('director'))
print(movie.findtext('year'))
# Out:
# 어벤져스
# 조스 웨던
# 2012

# %%
#Json

import json #json 데이터를 처리하기 위한 json 모듈
d = {"title": "어벤져스", "year":2012} #파이썬 딕셔너리

#딕셔너리 > JSON 문자열로 변환
d_str = json.dumps(d) #JSON 형식의 문자열로 변환
type(d_str)
# Out:
# str

# %%
d_str
# Out:
# '{"title": "\\uc5b4\\ubca4\\uc838\\uc2a4", "year": 2012}'

# %%
#json 문자열 > 파이썬 딕셔너리로 변환
d2 = json.loads(d_str)
print(type(d2))
# Out:
# <class 'dict'>

# %%
print(d2['title'])
# Out:
# 어벤져스
