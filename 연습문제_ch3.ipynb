# %% [markdown]
# <a href="https://colab.research.google.com/github/soo423/Python-archive/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_ch3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 연습문제 3장 모음

# %% [markdown]
# 기본 예제 문제 1

# %%
a = input()
print(a)
# Out:
# 3
# 3

# %%
a = input()
b = int(a)
print(b * 2)
# Out:
# 3
# 6

# %%
a = int(input())
print(a*2)
# Out:
# 3
# 6

# %% [markdown]
# 문제 2

# %%
a = abs(-5)
print(a)
# Out:
# 5

# %%
b = abs(5)
print(b)
# Out:
# 5

# %%
c = round(3.4)
print(c)
# Out:
# 3

# %%
d = round(3.5)
print(d)
# Out:
# 4

# %%
e = round(-5.2)
print(e)
# Out:
# -5

# %%
f = round(-5.5)
print(f)
# Out:
# -6

# %%
g = round(4.54, 1)
print(g)
# Out:
# 4.5

# %% [markdown]
# 문제3

# %%
a = "python"
print(len(a))
# Out:
# 6

# %%
b = ""
print(len(b))
# Out:
# 0

# %%
c = "ABC\nDEF"
print(len(c))
# Out:
# 7

# %%
d = [1,2,3]
print(len(d))
# Out:
# 3

# %%
e = [1, [2, 3]]
print(len(e))
# Out:
# 2

# %%
f = []
print(len(f))
# Out:
# 0

# %% [markdown]
# 문제4

# %%
a = [1,2,3]
print(sum(a))
# Out:
# 6

# %%
b = [3,4,5]
print(sum(b,1))
# Out:
# 13

# %%
c = [[1, 2], [0], [9]]
print(sum(c, []))
# Out:
# [1, 2, 0, 9]

# %%
d = [4, 5, 6]
print(max(d))
# Out:
# 6

# %%
e = [4, 5, 6]
print(min(e))
# Out:
# 4

# %%
print(max(4, 5, 6))
# Out:
# 6

# %%
print(min(4, 5, 6))
# Out:
# 4

# %% [markdown]
# 문제5

# %%
a = [5, 4, 2 ,6]
print(sorted(a))
# Out:
# [2, 4, 5, 6]

# %%
b = [5,4,2,6]
print(sorted(b, reverse = True))
# Out:
# [6, 5, 4, 2]

# %%
c = ["orange", "apple", "grape"]
print(sorted(c))
# Out:
# ['apple', 'grape', 'orange']

# %%
d = ["orange", "apple", "grape"]
print(sorted(d, reverse=True))
# Out:
# ['orange', 'grape', 'apple']

# %%
e = ["orange", "apple", "grape"]
print(sorted(e))
# Out:
# ['apple', 'grape', 'orange']

# %%
f = sorted("apple")
print(f)
# Out:
# ['a', 'e', 'l', 'p', 'p']

# %% [markdown]
# 문제6

# %%
a = 3
print("a = {}".format(a))
# Out:
# a = 3

# %%
a = 3
b = 4
print("b = {1}, a = {0}".format(a, b))
# Out:
# b = 4, a = 3

# %%
print("A = {a}, B = {b}".format(b=5, a=9))
# Out:
# A = 9, B = 5

# %%
print("A = {a}, B = {b}". format(a=9, b=5))
# Out:
# A = 9, B = 5

# %% [markdown]
# 문제 7

# %%
a = "Apple"
print(a.upper())
# Out:
# APPLE

# %%
b = "Banana"
print(b.lower())
# Out:
# banana

# %%
c = "41, 52"
print(c.upper())

# %%
d = "41, 52"
print(d.lower())
# Out:
# 41, 52

# %%
e = "1,2,3,4"
print(e.split())
# Out:
# ['1,2,3,4']

# %%
f = "1,2,3,4"
print(f.split(','))
# Out:
# ['1', '2', '3', '4']

# %%
g = "1,2,3,4"
print(g.split(", "))
# Out:
# ['1,2,3,4']

# %%
h = "1,2,3,4,5"
print(h.split(", "))
# Out:
# ['1,2,3,4,5']

# %% [markdown]
# 문제 8

# %%
a = [1,2,3]
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
b = [1, 2, 3]
b.append([4, 5])
print(b)
# Out:
# [1, 2, 3, [4, 5]]

# %%
c = [1, 2, 3]
c.append("four")
print(c)
# Out:
# [1, 2, 3, 'four']

# %%
d = ["apple", "grape", "banana"]
idx = d.index("apple")
print(idx)
# Out:
# 0

# %%
e = ["apple", "grape", "orange"]
p0 = e.pop(0)
print("p0 = {}, e = {} ".format(p0, e))
# Out:
# p0 = apple, e = ['grape', 'orange']

# %%
f = ["apple", "grape", "orange"]
pm1 = e.pop(-1)
print(f)
# Out:
# ['apple', 'grape', 'orange']

# %%
g = ["apple", "grape", "orange"]
gm1 = g.pop(-1)
gm1 = g.pop(-1)
print(g)
# Out:
# ['apple']

# %%
h = ["apple", "grape", "orange"]
h.remove("apple")
print(h)
# Out:
# ['grape', 'orange']

# %% [markdown]
# 심화 예제

# %% [markdown]
# 문제 9

# %%
a = input()
print(a*2)
# Out:
# 3
# 33

# %%
a = input()
b = input()
print(a + b)
# Out:
# 3
# 4
# 34

# %%
a = int(input())
print(a * 2)
# Out:
# 3
# 6

# %% [markdown]
# 문제10

# %%
a = input()
b = input()
c = int(a+b)
print(c)
# Out:
# 3
# 4
# 7

# %% [markdown]
# 문제 11

# %%
words = input()
words_list = words.split()
first = min(words_list)
print(first)
# Out:
# fox ape zebra
# ape

# %% [markdown]
# 문제 12

# %%
words = input()
words_list = words.split()
second = sorted(words_list[1])
print(second)
# Out:
# fox ape zebra
# ['a', 'e', 'p']
